# %% [markdown]
# This notebook demonstrates different techniques for handling missing values in datasets using pandas. It covers identifying missing data (isnull()), replacing with default values (fillna()), and using methods like forward fill (pad) and backward fill (bfill) to maintain data consistency.

# %%
import numpy as np
import pandas as pd

#dictionary of lists
dict = {'Marks': [100,90,np.nan, 95],
        'Rank': [1,2,4,np.nan],
        'Avg Marks': [np.nan, 40,80,98]}
df=pd.DataFrame(dict)
df
# Out:
#    Marks  Rank  Avg Marks
# 0  100.0   1.0        NaN
# 1   90.0   2.0       40.0
# 2    NaN   4.0       80.0
# 3   95.0   NaN       98.0

# %%
df.isnull()
# Out:
#    Marks   Rank  Avg Marks
# 0  False  False       True
# 1  False  False      False
# 2   True  False      False
# 3  False   True      False

# %%
df.fillna(0)
# Out:
#    Marks  Rank  Avg Marks
# 0  100.0   1.0        0.0
# 1   90.0   2.0       40.0
# 2    0.0   4.0       80.0
# 3   95.0   0.0       98.0

# %%
df.fillna(method='bfill')

#change the value or replace the values before to it
# Out:
# /tmp/ipython-input-2530876865.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')
#    Marks  Rank  Avg Marks
# 0  100.0   1.0       40.0
# 1   90.0   2.0       40.0
# 2   95.0   4.0       80.0
# 3   95.0   NaN       98.0

# %%
df.fillna(method='pad')

#change the value or replace the values next to it
# Out:
# /tmp/ipython-input-1227838480.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='pad')
#    Marks  Rank  Avg Marks
# 0  100.0   1.0        NaN
# 1   90.0   2.0       40.0
# 2   90.0   4.0       80.0
# 3   95.0   4.0       98.0

# %%
df.interpolate(method='linear', limit_direction='forward')

#using linear method and move inn forward direction and taking the mean of the othr values and filling the data
# Out:
#    Marks  Rank  Avg Marks
# 0  100.0   1.0        NaN
# 1   90.0   2.0       40.0
# 2   92.5   4.0       80.0
# 3   95.0   4.0       98.0

# %%
df.dropna()
# Out:
#    Marks  Rank  Avg Marks
# 1   90.0   2.0       40.0
